# %%
import cv2
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('building1.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=678x508>

# %%
if image is None:
        print('Could not read image')

# %%
kernel1 = np.array([[-1, 0, 1],
                          [-3, 0, 3],
                          [-1, 0, 1]])

# %%
fea_map = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)

# %%
cv2_imshow(image)
cv2_imshow(fea_map)
cv2.imwrite('feature_map1.jpg', fea_map)
# Out:
# <PIL.Image.Image image mode=RGB size=678x508>
# <PIL.Image.Image image mode=RGB size=678x508>
# True

# %%
cv2.imwrite('feature_map1.jpg', fea_map)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
kernel1 = np.array([[-1,-3,1],
                          [-1,0,1],
                          [1,3,1]])

# %%
kernel1 = np.array([[0,1,3],
                          [-1,0,1],
                          [-3,1,0]])

# %%
kernel1 = np.array([[-3,-1,0],
                          [-1,0,1],
                          [0,1,3]])

# %%
kernel1 = np.array([[-1,-1,0],
                          [-1,8,-1],
                          [-1,-1,-1]])

# %%
fea_map = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)

# %%
cv2_imshow(image)
cv2_imshow(fea_map)
cv2.imwrite('feature_map1.jpg', fea_map)
# Out:
# <PIL.Image.Image image mode=RGB size=678x508>
# <PIL.Image.Image image mode=RGB size=678x508>
# True
